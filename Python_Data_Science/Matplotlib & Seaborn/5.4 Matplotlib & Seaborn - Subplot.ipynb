# %%
# Copyright © 2022 Indonesia AI. All Rights Reserved.
# contact@aiforindonesia.org

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([6, 10, 4, 13])
plt.plot(xpoints, ypoints)

plt.show()

# %% [markdown]
# ### Membuat dua plot secara horizontal

# %%
# Plot 1
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(1, 2, 1) # 1 row 2 columns
plt.plot(x,y)

# Plot 2
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(1, 2, 2) # 1 row 2 columns
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Membuat dua plot secara vertikal

# %%
# Plot 1
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(2, 1, 1)  # 2 rows 1 column
plt.plot(x,y)

# Plot 2
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(2, 1, 2) # 2 rows 1 column
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Membuat banyak plot

# %%
plt.figure(figsize=(12, 6))

# Plot 1
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(2, 3, 1) # 2 row 3 columns
plt.plot(x,y)

# Plot 2
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(2, 3, 2) # 2 row 3 columns
plt.plot(x,y)

# Plot 3
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(2, 3, 3) # 2 row 3 columns
plt.plot(x,y)

# Plot 4
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(2, 3, 4) # 2 row 3 columns
plt.plot(x,y)

# Plot 5
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(2, 3, 5) # 2 row 3 columns
plt.plot(x,y)

# Plot 6
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(2, 3, 6) # 2 row 3 columns
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Memberi title pada dua plot

# %%
# Plot 1
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(1, 2, 1) # 1 row 2 columns
plt.plot(x,y)
plt.title('SALES')

# Plot 2
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(1, 2, 2) # 1 row 2 columns
plt.plot(x,y)
plt.title('INCOME')

plt.show()

# %% [markdown]
# ### Memberi title utama pada dua plot

# %%
plt.figure(figsize=(14, 4))

# Plot 1
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 10, 80])

plt.subplot(1, 2, 1) # 1 row 2 columns
plt.plot(x,y)
plt.title('USERS')

# Plot 2
x = np.array([0, 1, 2, 3])
y = np.array([30, 80, 90, 120])

plt.subplot(1, 2, 2) # 1 row 2 columns
plt.plot(x,y)
plt.title('INCOME')

plt.suptitle('TRACTION JUNE 2022')
plt.show()

# %% [markdown]
# ---
